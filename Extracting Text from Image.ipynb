# %% [markdown]
# # Extracting Text from an Image using 'Pytesseract'

# %% [markdown]
#  ##### Reference: https://pypi.org/project/pytesseract/

# %% [markdown]
# #### This library helps in image processing and performing computer vision tasks.

# %%
import cv2

# %% [markdown]
# #### This library used for data visualization and graphical plotting library.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### import the path of an image

# %%
book_img = cv2.imread("C:/Users/vishw/OneDrive/Documents/Imarticus/Python/Machine Learning/OpenCV/Image11.jpg")

# %% [markdown]
# #### plotting the image

# %%
plt.imshow(book_img)

# %% [markdown]
# #### this is an image of a book 'How to Win Friends and Influence People' by Dale Carnegie.

# %% [markdown]
# ## Python-tesseract is an optical character recognition (OCR) tool for python.
# ## That is, it will recognize and “read” the text embedded in images.

# %% [markdown]
# #### install and import 'Pytesseract' library

# %%
# !pip install pytesseract

# %%
import pytesseract as tess

# %% [markdown]
# #### PIL is the Python Imaging Library which provides the python interpreter with image editing capabilities.

# %%
from PIL import Image

# %% [markdown]
# #### Define the path

# %%
tess.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %% [markdown]
# #### Define and store a path of an image and return an image object.

# %%
book_img = Image.open("C:/Users/vishw/OneDrive/Documents/Imarticus/Python/Machine Learning/OpenCV/Image11.jpg")

# %% [markdown]
# #### This will extract all the text from an image and convert it into String.

# %%
text=tess.image_to_string(book_img)

# %% [markdown]
# #### print the output

# %%
print(text)
# Out:
# In A Nutshell
#
# SIX WAYS TO MAKE PEOPLE LIKE YOU
#
# PRINCIPLE |
# Become genuinely interested in other people.
#
# PRINCIPLE 2
# Smile. a
#
# PRINCIPLE 3
# Remember that a person’s name is to that person the-
# Sweetest and most important sound in any language.
#
# PRINCIPLE 4
# Be a good listener. Encourage others to talk about
# themselves.
#
# PRINCIPLE 5
# Talk in terms of the other person’s interests.
#
# PRINCIPLE 6
# Make the other person feel important— ‘
# and do it sincerely.
